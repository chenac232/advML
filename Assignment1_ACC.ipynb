# %% [markdown]
# # Assignment 1
# Anne Chen
#
# Github repo: https://github.com/chenac232/advML

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting aimodelshare
#   Downloading aimodelshare-0.0.178-py3-none-any.whl (966 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 967.0/967.0 KB 7.3 MB/s eta 0:00:00
# Collecting Pympler==0.9
#   Downloading Pympler-0.9.tar.gz (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 KB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting boto3==1.21.20
#   Downloading boto3-1.21.20-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 KB 2.5 MB/s eta 0:00:00
# Collecting psutil>=5.9.1
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 6.9 MB/s eta 0:00:00
# Collecting docker==5.0.0
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 KB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (2022.6.2)
# Requirement already satisfied: pydot==1.3.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.3.0)
# Collecting skl2onnx>=1.8.0
#   Downloading skl2onnx-1.13-py2.py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 KB 9.1 MB/s eta 0:00:00
# Collecting keras2onnx>=1.7.0
#   Downloading keras2onnx-1.7.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.3/96.3 KB 4.5 MB/s eta 0:00:00
# Collecting shortuuid>=1.0.8
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: seaborn>=0.11.2 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (0.11.2)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.6.3)
# Collecting onnxmltools>=1.6.1
#   Downloading onnxmltools-1.11.1-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.6/308.6 KB 22.2 MB/s eta 0:00:00
# Collecting wget==3.2
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting importlib-resources==5.10.0
#   Downloading importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Collecting PyJWT>=2.4.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting botocore==1.24.20
#   Downloading botocore-1.24.20-py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 21.6 MB/s eta 0:00:00
# Collecting onnxruntime>=1.7.0
#   Downloading onnxruntime-1.13.1-cp38-cp38-manylinux_2_27_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 27.1 MB/s eta 0:00:00
# Collecting onnxconverter-common>=1.7.0
#   Downloading onnxconverter_common-1.13.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 KB 4.8 MB/s eta 0:00:00
# Collecting tf2onnx
#   Downloading tf2onnx-1.13.0-py3-none-any.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.3/442.3 KB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow==2.9.2 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (2.9.2)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.13.1+cu116)
# Collecting onnx==1.12.0
#   Downloading onnx-1.12.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 44.7 MB/s eta 0:00:00
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.0.1)
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.8/dist-packages (from astunparse==1.6.3->aimodelshare) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse==1.6.3->aimodelshare) (0.38.4)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 8.2 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore==1.24.20->aimodelshare) (2.8.2)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /usr/local/lib/python3.8/dist-packages (from docker==5.0.0->aimodelshare) (2.25.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources==5.10.0->aimodelshare) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (4.4.0)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (3.19.6)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (1.21.6)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.8/dist-packages (from pydot==1.3.0->aimodelshare) (3.0.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (3.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (1.7.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.51.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (23.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.12)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.30.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (57.4.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (15.0.6.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (3.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.4.0)
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from onnxruntime>=1.7.0->aimodelshare) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.8/dist-packages (from seaborn>=0.11.2->aimodelshare) (3.2.2)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.8/dist-packages (from seaborn>=0.11.2->aimodelshare) (1.3.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.23->seaborn>=0.11.2->aimodelshare) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2.10)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.16.0)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy->onnxruntime>=1.7.0->aimodelshare) (1.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (6.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.2.2)
# Building wheels for collected packages: Pympler, wget, fire
#   Building wheel for Pympler (setup.py) ... done
#   Created wheel for Pympler: filename=Pympler-0.9-py3-none-any.whl size=164822 sha256=7bf9d6c65fd362cadfa39dbbac30c5c443510408e92a6cb62f906fca86f857f5
#   Stored in directory: /root/.cache/pip/wheels/24/6f/0b/da9f81234859a8741aaea3afcc6ae2daf0efb67e7ff2d3686c
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=76b694fa5b7376615c1b0037c2af74b818dab49b67998efff96de7b6c87bb430
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116949 sha256=8aec6ab80cf47a0a74603e95fb58acfdb564e46862dc8d9603085173cc711512
#   Stored in directory: /root/.cache/pip/wheels/5b/eb/43/7295e71293b218ddfd627f935229bf54af9018add7fbb5aac6
# Successfully built Pympler wget fire
# Installing collected packages: wget, Pympler, websocket-client, urllib3, shortuuid, PyJWT, psutil, onnx, jmespath, importlib-resources, humanfriendly, fire, scikit-learn, onnxconverter-common, coloredlogs, botocore, tf2onnx, skl2onnx, s3transfer, onnxruntime, keras2onnx, docker, onnxmltools, boto3, aimodelshare
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 5.10.2
#     Uninstalling importlib-resources-5.10.2:
#       Successfully uninstalled importlib-resources-5.10.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed PyJWT-2.6.0 Pympler-0.9 aimodelshare-0.0.178 boto3-1.21.20 botocore-1.24.20 coloredlogs-15.0.1 docker-5.0.0 fire-0.5.0 humanfriendly-10.0 importlib-resources-5.10.0 jmespath-0.10.0 keras2onnx-1.7.0 onnx-1.12.0 onnxconverter-common-1.13.0 onnxmltools-1.11.1 onnxruntime-1.13.1 psutil-5.9.4 s3transfer-0.5.2 scikit-learn-0.24.2 shortuuid-1.0.11 skl2onnx-1.13 tf2onnx-1.13.0 urllib3-1.26.14 websocket-client-1.5.1 wget-3.2

# %%
#Get competition data from course folder and unzip
# importing the zipfile module
from zipfile import ZipFile
  
# loading the temp.zip and creating a zip object
with ZipFile("world_happiness_competition_data.zip", 'r') as zObject:
  
    # Extracting all the members of the zip 
    # into a specific location.
    zObject.extractall()

# %%
# Load data
import pandas as pd
X_train = pd.read_csv('world_happiness_competition_data/X_train.csv')
X_test = pd.read_csv('world_happiness_competition_data/X_test.csv')
y_train = pd.read_csv('world_happiness_competition_data/y_train.csv')
y_train_labels = y_train.idxmax(axis=1)

X_train.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0              Peru           0.960           1.274                    0.854
# 1         Nicaragua           0.694           1.325                    0.835
# 2            Greece           1.181           1.156                    0.999
# 3             Qatar           1.684           1.313                    0.871
# 4        Uzbekistan           0.745           1.529                    0.756
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.455       0.083                      0.027
# 1                         0.435       0.200                      0.127
# 2                         0.067       0.000                      0.034
# 3                         0.555       0.220                      0.167
# 4                         0.631       0.322                      0.240
#
#          name    region                       sub-region  Terrorist_attacks
# 0        Peru  Americas  Latin America and the Caribbean          18.000000
# 1   Nicaragua  Americas  Latin America and the Caribbean         125.611111
# 2      Greece    Europe                  Southern Europe         112.000000
# 3       Qatar      Asia                     Western Asia          57.333333
# 4  Uzbekistan      Asia                     Central Asia         125.611111

# %% [markdown]
# ### View the data

# %%
X_train.describe()
# Out:
#        GDP per capita  Social support  Healthy life expectancy  \
# count       88.000000       88.000000                88.000000
# mean         0.917148        1.213807                 0.745693
# std          0.412638        0.293830                 0.237671
# min          0.026000        0.000000                 0.105000
# 25%          0.626000        1.113250                 0.567000
# 50%          0.960000        1.249500                 0.806500
# 75%          1.249000        1.463500                 0.898250
# max          1.684000        1.624000                 1.141000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                     88.000000   88.000000                  88.000000
# mean                       0.379273    0.184705                   0.115159
# std                        0.156634    0.102516                   0.103309
# min                        0.000000    0.000000                   0.000000
# 25%                        0.267750    0.106750                   0.049250
# 50%                        0.408000    0.179500                   0.083500
# 75%                        0.493500    0.244500                   0.145750
# max                        0.631000    0.566000                   0.453000
#
#        Terrorist_attacks
# count          88.000000
# mean          296.720179
# std           764.351472
# min             1.000000
# 25%             4.750000
# 50%            38.500000
# 75%           125.611111
# max          6023.000000

# %%
X_train.dtypes
# Out:
# Country or region                object
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# name                             object
# region                           object
# sub-region                       object
# Terrorist_attacks               float64
# dtype: object

# %%
y_train.describe()
# Out:
#          Average       High        Low  Very High   Very Low
# count  88.000000  88.000000  88.000000  88.000000  88.000000
# mean    0.193182   0.250000   0.181818   0.170455   0.204545
# std     0.397057   0.435494   0.387905   0.378187   0.405681
# min     0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.250000   0.000000   0.000000   0.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000

# %% [markdown]
# ## 1. Explore Bivariate results
# Describe any relationships you see between particular features and the target variable
#
# - We'll look at GDP per capita, perceptions of corruption and happiness.

# %%
import pandas as pd

# Merge y_train and x_train to look at relationship between specific features and the target variable
df = pd.merge(X_train, y_train, right_index=True, left_index=True)

# recode y_train column to a "happiness" column
df['happy'] = 0
df.loc[(df['Very Low']==1), 'happy'] = 1
df.loc[(df['Low']==1), 'happy'] = 2
df.loc[(df['Average']==1), 'happy'] = 3
df.loc[(df['High']==1), 'happy'] = 4
df.loc[(df['Very High']==1), 'happy'] = 5

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create box plot for features
f2, ax = plt.subplots(2, 2, figsize=(16, 12))
sns.boxplot('happy', 'GDP per capita', data=df, ax=ax[0, 0], palette='Blues')
sns.boxplot('happy', 'Perceptions of corruption', data=df, ax=ax[0, 1], palette='Blues')
sns.boxplot('happy', 'Terrorist_attacks', data=df, ax=ax[1, 0], palette='Blues')
sns.boxplot('happy', 'Social support', data=df, ax=ax[1, 1], palette='Blues')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# We can see from the boxplots above that GDP per capita has the most linear relationship with happiness. The greater GDP per capita, generally, the greater happiness. For other features, it's a little less linear to determine. Perceptions of corruption and terrorist attacks do not appear to have a linear relationship with how happy people are. Social support is a relatively strong indicator of happiness. Countries with greater social support tend to have greater happiness.

# %% [markdown]
# # 2. Examine features that predict happiness categories using one or more models that allow for automatic feature selection
# Explain any meaningful findings

# %% [markdown]
# ## 1. PCA

# %%
# PCA implementation
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

numeric_features = df.drop(['Country or region', 'name', 'region', 'sub-region'], axis=1)
# numeric_features=numeric_features.columns.tolist()

# %%
numeric_features.head(5)
# Out:
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           0.960           1.274                    0.854
# 1           0.694           1.325                    0.835
# 2           1.181           1.156                    0.999
# 3           1.684           1.313                    0.871
# 4           0.745           1.529                    0.756
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.455       0.083                      0.027
# 1                         0.435       0.200                      0.127
# 2                         0.067       0.000                      0.034
# 3                         0.555       0.220                      0.167
# 4                         0.631       0.322                      0.240
#
#    Terrorist_attacks  Average  High  Low  Very High  Very Low  happy
# 0          18.000000        1     0    0          0         0      3
# 1         125.611111        0     1    0          0         0      4
# 2         112.000000        1     0    0          0         0      3
# 3          57.333333        0     0    0          1         0      5
# 4         125.611111        0     1    0          0         0      4

# %%
df = numeric_features
X = pd.DataFrame(scale(df), index=df.index, columns=df.columns)

# fit PCA with 2 components
pca = PCA(n_components=2)
pca.fit_transform(X)
# Out:
# array([[-0.25943089, -1.49775523],
#        [-0.91180912, -0.61249436],
#        [ 0.2129572 , -2.48349548],
#        [-2.92128422,  1.38173757],
#        [-1.74319526,  0.70313541],
#        [ 0.8822404 , -0.79052286],
#        [-1.95517638,  0.54347814],
#        [-2.81841169,  0.70663445],
#        [ 1.29003567, -1.07429322],
#        [-1.5506657 , -1.48604919],
#        [ 1.53203731, -0.19856291],
#        [ 3.87392787,  1.4743885 ],
#        [ 1.68552511,  2.84666471],
#        [ 3.18220114,  0.43253885],
#        [-0.97196182, -1.74759565],
#        [ 1.01389529, -1.0226204 ],
#        [-0.80855703, -2.15869982],
#        [ 0.44200673, -0.14076869],
#        [-3.37366866,  0.91499691],
#        [ 3.20374734,  0.94571505],
#        [ 2.54596777,  0.81214259],
#        [-1.22615275, -0.86075197],
#        [ 5.15620188,  1.41275828],
#        [ 2.10157957, -0.28030634],
#        [-1.03883947, -1.64516924],
#        [-3.70072202,  2.26391525],
#        [ 0.78851751,  0.14333901],
#        [ 3.54771025,  1.19509223],
#        [-1.19712792, -1.14421661],
#        [-1.43503126, -1.82043594],
#        [-0.33733485, -1.32855211],
#        [ 0.44624634, -0.90236798],
#        [-0.66715021, -1.35115536],
#        [-1.38641525, -1.72398384],
#        [-3.66841856,  2.81730895],
#        [-1.95995188, -1.25449347],
#        [ 0.53516903, -1.33160302],
#        [ 2.56074501,  0.02310063],
#        [-0.02849734,  0.73847155],
#        [ 0.03639306, -1.01488363],
#        [ 3.52784492,  1.39280087],
#        [ 3.75816424,  1.45174115],
#        [-0.16841161, -1.16622622],
#        [-3.52447663,  2.27439851],
#        [-3.54284357,  1.7482219 ],
#        [-1.32719933, -1.19874137],
#        [ 2.50868697,  1.1179095 ],
#        [-3.29636326,  1.77807479],
#        [-2.96551419,  1.10546073],
#        [-1.27346906, -1.20786166],
#        [-0.13748828, -1.40528463],
#        [ 2.38917121,  0.19478108],
#        [-3.58826702,  2.4622412 ],
#        [ 2.66729783,  1.62139419],
#        [ 0.44473898, -0.66128344],
#        [-3.82413311,  2.32111135],
#        [ 1.49223506,  0.68306882],
#        [-0.92225626, -0.47726849],
#        [ 0.97863547, -1.10516013],
#        [-1.93345241, -1.09902744],
#        [ 0.716612  , -1.65852556],
#        [-1.68850353, -1.14466078],
#        [ 5.95327206,  1.4513798 ],
#        [-0.82071972, -0.47005977],
#        [-1.44944665, -1.27726523],
#        [ 0.59946397, -1.34467775],
#        [-3.07406104,  2.04966976],
#        [-2.07649843, -1.50225241],
#        [ 3.49944627,  0.59015938],
#        [ 1.01501284,  0.89479903],
#        [-1.27489911, -1.83653752],
#        [ 3.98573017,  2.17263168],
#        [-3.78193941,  2.54670226],
#        [-1.01799416, -1.89407692],
#        [ 1.33372295,  3.31934747],
#        [ 1.06523629, -1.34876983],
#        [ 1.01398165,  0.29607824],
#        [ 0.82844025,  0.08388328],
#        [ 0.50624575, -1.61228312],
#        [-0.24048419, -1.63718504],
#        [ 1.98539068, -1.08818305],
#        [ 4.15468109,  0.84235361],
#        [-2.81369647,  1.76724908],
#        [ 0.11038707, -0.45157625],
#        [ 0.91262927, -0.68808691],
#        [-3.07716892,  2.34753458],
#        [-0.46951489, -1.19692003],
#        [ 1.76447212, -0.52571946]])

# %%
# The loading vectors
pca_loadings = pd.DataFrame(PCA(n_components=2).fit(X).components_.T, index=df.columns)
pca_loadings
# Out:
#                                      0         1
# GDP per capita               -0.391653 -0.096328
# Social support               -0.364872 -0.097710
# Healthy life expectancy      -0.382545 -0.100800
# Freedom to make life choices -0.292751  0.220058
# Generosity                   -0.036460  0.504789
# Perceptions of corruption    -0.221573  0.437265
# Terrorist_attacks             0.216535  0.145507
# Average                       0.010229 -0.241348
# High                         -0.156311 -0.325543
# Low                           0.111830 -0.127606
# Very High                    -0.280712  0.408216
# Very Low                      0.312544  0.327148
# happy                        -0.413031 -0.035014

# %% [markdown]
# From the table above, we can see that GDP per capita, social support, and healthy life expectancy tend to be strong determinents of happiness relative to the other variables present.

# %%
print(pca.components_)
# Out:
# [[-0.39165325 -0.36487247 -0.3825448  -0.29275108 -0.0364601  -0.22157334
#    0.21653451  0.01022889 -0.15631101  0.1118299  -0.28071156  0.312544
#   -0.41303075]
#  [-0.09632793 -0.09771005 -0.10080027  0.22005751  0.50478883  0.43726512
#    0.14550726 -0.24134811 -0.32554263 -0.12760571  0.40821624  0.32714849
#   -0.03501405]]

# %%
print(pca.explained_variance_) # explained variance for for each principal component vector
# Out:
# [5.28697732 2.10515791]

# %%
pca.explained_variance_ratio_
# Out:
# array([0.40206908, 0.16009505])

# %% [markdown]
# First PCA explains about 40 percent of the variance, second PCA explains 16 percent of the variance

# %% [markdown]
# From the heatmap above, we can examine how correlated happiness is with each of the variables. We see that similar to the PCA results, GDP per capita, healthy life expectancy, and social support have the strongest correlation with happiness.

# %% [markdown]
# # 3. Experiment with different prediction models to try to predict World Happiness well
# (Fit and compare, at minimum, three models)
# - submit three models to the model share leaderboard before you start communicating with your team.
# - After you submit your first three models, describe your best model with your team via your team slack channel
# Fit and submit up to three more models after learning from your team.
# - Discuss which models you tried and which models performed better and point out relevant hyper-parameter values for successful models.
# - Submit your best models to the leaderboard for the World Happiness AI Model Share competition.
#  - You have the option to present and/or discuss these models in your report, but it is not required.

# %% [markdown]
# ## Initial 3 Models

# %% [markdown]
# ### Set up

# %%
# Set up preprocessing

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# We create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.drop(['Country or region', 'name', 'region', 'sub-region'], axis=1)
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['region', 'sub-region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %%
# Write function to transform data with preprocessor

def preprocessor(data):
    data.drop(['Country or region', 'name'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (88, 26)

# %% [markdown]
# ### 1. Random Forest Classifier
# With n_estimators = 200 and max_depth=5

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=200, max_depth=5)
model.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.9318181818181818

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from sklearn.ensemble import RandomForestClassifier

model_2 = RandomForestClassifier(n_estimators=200, max_depth=10)
model_2.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model_2.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 1.0

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model_2, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this World Happiness Classification Playground -- make sure to update the apiurl for new competition deployments
# apiurl="https://e2w6gh3id1.execute-api.us-east-2.amazonaws.com/prod/m"
apiurl = 'https://e2w6gh3id1.execute-api.us-east-2.amazonaws.com/prod/m'

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip",
                           custom_metadata={'team': '5'})
# Out:
# Insert search tags to help users find your model (optional): initial model
# Provide any useful notes about your model (optional): initial model
#
# Your model has been submitted as model version 548
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# ### 2. Gradient Boosting Classifier
#
# With n_estimators=100, learning_rate=1.0, max_depth = 1

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

#Example code to fit model:
model = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=1, random_state=0).fit(preprocessor(X_train), y_train_labels)
model.score(preprocessor(X_train), y_train_labels)

# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values 
prediction_labels = model.predict(preprocessor(X_test))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                                 custom_metadata={'team': '5'})
# Out:
# Insert search tags to help users find your model (optional): initial model
# Provide any useful notes about your model (optional): initial model
#
# Your model has been submitted as model version 551
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# ### 3. Original Neural Network
#
# With batch size = 15, epochs = 300

# %%
# Or you can experiment with deep learning models: 
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

feature_count=preprocessor(X_train).shape[1] #count features in input data

keras_model = Sequential()
keras_model.add(Dense(128, input_dim=feature_count, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(32, activation='relu'))

keras_model.add(Dense(5, activation='softmax')) 
                                            
# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
keras_model.fit(preprocessor(X_train), y_train, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 15, 
               epochs = 300, validation_split=0.25)
# Out:
# Epoch 1/300
# 5/5 [==============================] - 1s 95ms/step - loss: 1.6404 - accuracy: 0.1818 - val_loss: 1.5914 - val_accuracy: 0.2727
# Epoch 2/300
# 5/5 [==============================] - 0s 17ms/step - loss: 1.6271 - accuracy: 0.1667 - val_loss: 1.5873 - val_accuracy: 0.3182
# Epoch 3/300
# 5/5 [==============================] - 0s 17ms/step - loss: 1.6152 - accuracy: 0.1818 - val_loss: 1.5829 - val_accuracy: 0.2727
# Epoch 4/300
# 5/5 [==============================] - 0s 16ms/step - loss: 1.6010 - accuracy: 0.1970 - val_loss: 1.5800 - val_accuracy: 0.2727
# Epoch 5/300
# 5/5 [==============================] - 0s 14ms/step - loss: 1.5881 - accuracy: 0.2273 - val_loss: 1.5763 - val_accuracy: 0.2727
# Epoch 6/300
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5763 - accuracy: 0.2727 - val_loss: 1.5720 - val_accuracy: 0.2727
# Epoch 7/300
# 5/5 [==============================] - 0s 14ms/step - loss: 1.5647 - accuracy: 0.2879 - val_loss: 1.5687 - val_accuracy: 0.2273
# Epoch 8/300
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5541 - accuracy: 0.3182 - val_loss: 1.5655 - val_accuracy: 0.2727
# Epoch 9/300
# 5/5 [==============================] - 0s 14ms/step - loss: 1.5434 - accuracy: 0.3636 - val_loss: 1.5611 - val_accuracy: 0.3182
# Epoch 10/300
# 5/5 [==============================] - 0s 15ms/step - loss: 1.5331 - accuracy: 0.3788 - val_loss: 1.5562 - val_accuracy: 0.2727
# Epoch 11/300
# 5/5 [==============================] - 0s 19ms/step - loss: 1.5232 - accuracy: 0.4091 - val_loss: 1.5522 - val_accuracy: 0.2727
# Epoch 12/300
# 5/5 [==============================] - 0s 18ms/step - loss: 1.5132 - accuracy: 0.4697 - val_loss: 1.5466 - val_accuracy: 0.2727
# Epoch 13/300
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5025 - accuracy: 0.4848 - val_loss: 1.5407 - val_accuracy: 0.2727
# Epoch 14/300
# 5/5 [==============================] - 0s 23ms/step - loss: 1.4931 - accuracy: 0.4697 - val_loss: 1.5360 - val_accuracy: 0.3182
# Epoch 15/300
# 5/5 [==============================] - 0s 19ms/step - loss: 1.4831 - accuracy: 0.5152 - val_loss: 1.5294 - val_accuracy: 0.3182
# Epoch 16/300
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4714 - accuracy: 0.5152 - val_loss: 1.5225 - val_accuracy: 0.3182
# Epoch 17/300
# 5/5 [==============================] - 0s 19ms/step - loss: 1.4621 - accuracy: 0.5152 - val_loss: 1.5183 - val_accuracy: 0.3182
# Epoch 18/300
# 5/5 [==============================] - 0s 18ms/step - loss: 1.4515 - accuracy: 0.5455 - val_loss: 1.5130 - val_accuracy: 0.3182
# Epoch 19/300
# 5/5 [==============================] - 0s 19ms/step - loss: 1.4415 - accuracy: 0.5303 - val_loss: 1.5063 - val_accuracy: 0.3182
# Epoch 20/300
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4309 - accuracy: 0.5455 - val_loss: 1.4983 - val_accuracy: 0.3182
# Epoch 21/300
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4189 - accuracy: 0.5455 - val_loss: 1.4912 - val_accuracy: 0.3182
# Epoch 22/300
# 5/5 [==============================] - 0s 19ms/step - loss: 1.4081 - accuracy: 0.5455 - val_loss: 1.4837 - val_accuracy: 0.3182
# Epoch 23/300
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3970 - accuracy: 0.5455 - val_loss: 1.4759 - val_accuracy: 0.3636
# Epoch 24/300
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3861 - accuracy: 0.5455 - val_loss: 1.4701 - val_accuracy: 0.3182
# Epoch 25/300
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3754 - accuracy: 0.5455 - val_loss: 1.4634 - val_accuracy: 0.3636
# Epoch 26/300
# 5/5 [==============================] - 0s 17ms/step - loss: 1.3653 - accuracy: 0.5606 - val_loss: 1.4568 - val_accuracy: 0.3636
# Epoch 27/300
# 5/5 [==============================] - 0s 17ms/step - loss: 1.3541 - accuracy: 0.5606 - val_loss: 1.4488 - val_accuracy: 0.3636
# Epoch 28/300
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3441 - accuracy: 0.5606 - val_loss: 1.4410 - val_accuracy: 0.3636
# Epoch 29/300
# 5/5 [==============================] - 0s 18ms/step - loss: 1.3327 - accuracy: 0.5606 - val_loss: 1.4336 - val_accuracy: 0.3636
# Epoch 30/300
# 5/5 [==============================] - 0s 17ms/step - loss: 1.3213 - accuracy: 0.5606 - val_loss: 1.4264 - val_accuracy: 0.3636
# Epoch 31/300
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3116 - accuracy: 0.5606 - val_loss: 1.4167 - val_accuracy: 0.3636
# Epoch 32/300
# 5/5 [==============================] - 0s 19ms/step - loss: 1.3002 - accuracy: 0.5606 - val_loss: 1.4080 - val_accuracy: 0.3636
# Epoch 33/300
# 5/5 [==============================] - 0s 19ms/step - loss: 1.2890 - accuracy: 0.5606 - val_loss: 1.4033 - val_accuracy: 0.3636
# Epoch 34/300
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2794 - accuracy: 0.5606 - val_loss: 1.3950 - val_accuracy: 0.3636
# Epoch 35/300
# 5/5 [==============================] - 0s 16ms/step - loss: 1.2679 - accuracy: 0.5606 - val_loss: 1.3891 - val_accuracy: 0.3636
# Epoch 36/300
# 5/5 [==============================] - 0s 19ms/step - loss: 1.2584 - accuracy: 0.5606 - val_loss: 1.3796 - val_accuracy: 0.3636
# Epoch 37/300
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2474 - accuracy: 0.5606 - val_loss: 1.3732 - val_accuracy: 0.3636
# Epoch 38/300
# 5/5 [==============================] - 0s 18ms/step - loss: 1.2394 - accuracy: 0.5758 - val_loss: 1.3650 - val_accuracy: 0.3636
# Epoch 39/300
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2275 - accuracy: 0.5606 - val_loss: 1.3587 - val_accuracy: 0.3636
# Epoch 40/300
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2174 - accuracy: 0.5758 - val_loss: 1.3515 - val_accuracy: 0.3636
# Epoch 41/300
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2082 - accuracy: 0.5758 - val_loss: 1.3450 - val_accuracy: 0.3636
# Epoch 42/300
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1969 - accuracy: 0.5758 - val_loss: 1.3380 - val_accuracy: 0.3636
# Epoch 43/300
# 5/5 [==============================] - 0s 15ms/step - loss: 1.1869 - accuracy: 0.5758 - val_loss: 1.3292 - val_accuracy: 0.4091
# Epoch 44/300
# 5/5 [==============================] - 0s 13ms/step - loss: 1.1768 - accuracy: 0.5758 - val_loss: 1.3211 - val_accuracy: 0.4545
# Epoch 45/300
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1663 - accuracy: 0.6061 - val_loss: 1.3149 - val_accuracy: 0.4545
# Epoch 46/300
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1567 - accuracy: 0.5909 - val_loss: 1.3089 - val_accuracy: 0.4545
# Epoch 47/300
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1463 - accuracy: 0.5758 - val_loss: 1.3035 - val_accuracy: 0.4545
# Epoch 48/300
# 5/5 [==============================] - 0s 12ms/step - loss: 1.1363 - accuracy: 0.6212 - val_loss: 1.2956 - val_accuracy: 0.4545
# Epoch 49/300
# 5/5 [==============================] - 0s 9ms/step - loss: 1.1250 - accuracy: 0.6364 - val_loss: 1.2879 - val_accuracy: 0.4545
# Epoch 50/300
# 5/5 [==============================] - 0s 10ms/step - loss: 1.1142 - accuracy: 0.6212 - val_loss: 1.2809 - val_accuracy: 0.4545
# Epoch 51/300
# 5/5 [==============================] - 0s 13ms/step - loss: 1.1057 - accuracy: 0.6364 - val_loss: 1.2746 - val_accuracy: 0.5000
# Epoch 52/300
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0932 - accuracy: 0.6364 - val_loss: 1.2660 - val_accuracy: 0.5000
# Epoch 53/300
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0838 - accuracy: 0.6364 - val_loss: 1.2585 - val_accuracy: 0.5000
# Epoch 54/300
# 5/5 [==============================] - 0s 11ms/step - loss: 1.0719 - accuracy: 0.6515 - val_loss: 1.2524 - val_accuracy: 0.5000
# Epoch 55/300
# 5/5 [==============================] - 0s 10ms/step - loss: 1.0617 - accuracy: 0.6515 - val_loss: 1.2469 - val_accuracy: 0.5000
# Epoch 56/300
# 5/5 [==============================] - 0s 11ms/step - loss: 1.0508 - accuracy: 0.6515 - val_loss: 1.2381 - val_accuracy: 0.5000
# Epoch 57/300
# 5/5 [==============================] - 0s 10ms/step - loss: 1.0392 - accuracy: 0.6818 - val_loss: 1.2303 - val_accuracy: 0.5000
# Epoch 58/300
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0296 - accuracy: 0.6970 - val_loss: 1.2185 - val_accuracy: 0.5455
# Epoch 59/300
# 5/5 [==============================] - 0s 10ms/step - loss: 1.0180 - accuracy: 0.6818 - val_loss: 1.2130 - val_accuracy: 0.5000
# Epoch 60/300
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0073 - accuracy: 0.6818 - val_loss: 1.2069 - val_accuracy: 0.5000
# Epoch 61/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9970 - accuracy: 0.6970 - val_loss: 1.1989 - val_accuracy: 0.5000
# Epoch 62/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9888 - accuracy: 0.6970 - val_loss: 1.1914 - val_accuracy: 0.5000
# Epoch 63/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9781 - accuracy: 0.6818 - val_loss: 1.1862 - val_accuracy: 0.5000
# Epoch 64/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9639 - accuracy: 0.6818 - val_loss: 1.1832 - val_accuracy: 0.5000
# Epoch 65/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9537 - accuracy: 0.6818 - val_loss: 1.1732 - val_accuracy: 0.5000
# Epoch 66/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.9462 - accuracy: 0.6818 - val_loss: 1.1644 - val_accuracy: 0.5000
# Epoch 67/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9308 - accuracy: 0.7121 - val_loss: 1.1568 - val_accuracy: 0.5000
# Epoch 68/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9211 - accuracy: 0.7273 - val_loss: 1.1448 - val_accuracy: 0.5000
# Epoch 69/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9108 - accuracy: 0.7424 - val_loss: 1.1406 - val_accuracy: 0.5000
# Epoch 70/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8983 - accuracy: 0.7424 - val_loss: 1.1317 - val_accuracy: 0.5000
# Epoch 71/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8891 - accuracy: 0.7424 - val_loss: 1.1315 - val_accuracy: 0.5000
# Epoch 72/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8796 - accuracy: 0.7424 - val_loss: 1.1217 - val_accuracy: 0.5000
# Epoch 73/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8679 - accuracy: 0.7727 - val_loss: 1.1210 - val_accuracy: 0.5000
# Epoch 74/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8569 - accuracy: 0.7727 - val_loss: 1.1183 - val_accuracy: 0.5000
# Epoch 75/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8465 - accuracy: 0.7576 - val_loss: 1.1146 - val_accuracy: 0.5000
# Epoch 76/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8349 - accuracy: 0.8030 - val_loss: 1.1076 - val_accuracy: 0.5000
# Epoch 77/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8251 - accuracy: 0.7576 - val_loss: 1.0996 - val_accuracy: 0.5000
# Epoch 78/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8163 - accuracy: 0.7879 - val_loss: 1.0879 - val_accuracy: 0.5000
# Epoch 79/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8071 - accuracy: 0.7879 - val_loss: 1.0808 - val_accuracy: 0.5455
# Epoch 80/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7942 - accuracy: 0.8182 - val_loss: 1.0794 - val_accuracy: 0.5455
# Epoch 81/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7861 - accuracy: 0.7879 - val_loss: 1.0719 - val_accuracy: 0.5455
# Epoch 82/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7737 - accuracy: 0.8030 - val_loss: 1.0664 - val_accuracy: 0.5455
# Epoch 83/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7636 - accuracy: 0.8333 - val_loss: 1.0738 - val_accuracy: 0.5455
# Epoch 84/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7540 - accuracy: 0.7879 - val_loss: 1.0714 - val_accuracy: 0.5455
# Epoch 85/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7452 - accuracy: 0.8030 - val_loss: 1.0592 - val_accuracy: 0.5000
# Epoch 86/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7368 - accuracy: 0.8182 - val_loss: 1.0540 - val_accuracy: 0.5455
# Epoch 87/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7288 - accuracy: 0.8333 - val_loss: 1.0615 - val_accuracy: 0.5455
# Epoch 88/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7191 - accuracy: 0.8182 - val_loss: 1.0556 - val_accuracy: 0.5455
# Epoch 89/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7111 - accuracy: 0.8333 - val_loss: 1.0486 - val_accuracy: 0.5455
# Epoch 90/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7009 - accuracy: 0.8333 - val_loss: 1.0375 - val_accuracy: 0.5455
# Epoch 91/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6970 - accuracy: 0.8333 - val_loss: 1.0290 - val_accuracy: 0.5455
# Epoch 92/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6896 - accuracy: 0.8030 - val_loss: 1.0316 - val_accuracy: 0.5909
# Epoch 93/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6786 - accuracy: 0.8182 - val_loss: 1.0254 - val_accuracy: 0.5909
# Epoch 94/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6707 - accuracy: 0.8333 - val_loss: 1.0307 - val_accuracy: 0.5455
# Epoch 95/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6681 - accuracy: 0.8333 - val_loss: 1.0407 - val_accuracy: 0.5000
# Epoch 96/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6550 - accuracy: 0.8485 - val_loss: 1.0308 - val_accuracy: 0.5455
# Epoch 97/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6566 - accuracy: 0.8485 - val_loss: 1.0166 - val_accuracy: 0.5455
# Epoch 98/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6391 - accuracy: 0.8485 - val_loss: 1.0267 - val_accuracy: 0.5000
# Epoch 99/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6311 - accuracy: 0.8333 - val_loss: 1.0215 - val_accuracy: 0.5000
# Epoch 100/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6266 - accuracy: 0.8333 - val_loss: 1.0178 - val_accuracy: 0.5455
# Epoch 101/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6218 - accuracy: 0.8333 - val_loss: 1.0075 - val_accuracy: 0.5455
# Epoch 102/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6123 - accuracy: 0.8485 - val_loss: 1.0163 - val_accuracy: 0.5455
# Epoch 103/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.6034 - accuracy: 0.8485 - val_loss: 1.0270 - val_accuracy: 0.5000
# Epoch 104/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6035 - accuracy: 0.8182 - val_loss: 1.0220 - val_accuracy: 0.5000
# Epoch 105/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5906 - accuracy: 0.8485 - val_loss: 1.0085 - val_accuracy: 0.5000
# Epoch 106/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5861 - accuracy: 0.8333 - val_loss: 1.0200 - val_accuracy: 0.5000
# Epoch 107/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5819 - accuracy: 0.8485 - val_loss: 0.9981 - val_accuracy: 0.5455
# Epoch 108/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5801 - accuracy: 0.8333 - val_loss: 1.0001 - val_accuracy: 0.5909
# Epoch 109/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5701 - accuracy: 0.8333 - val_loss: 0.9897 - val_accuracy: 0.5455
# Epoch 110/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5591 - accuracy: 0.8485 - val_loss: 1.0051 - val_accuracy: 0.5455
# Epoch 111/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5561 - accuracy: 0.8333 - val_loss: 1.0178 - val_accuracy: 0.5455
# Epoch 112/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5549 - accuracy: 0.8636 - val_loss: 1.0062 - val_accuracy: 0.5455
# Epoch 113/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5452 - accuracy: 0.8636 - val_loss: 0.9909 - val_accuracy: 0.5909
# Epoch 114/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5400 - accuracy: 0.8333 - val_loss: 1.0056 - val_accuracy: 0.5455
# Epoch 115/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5338 - accuracy: 0.8636 - val_loss: 0.9921 - val_accuracy: 0.5000
# Epoch 116/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5303 - accuracy: 0.8485 - val_loss: 0.9862 - val_accuracy: 0.5000
# Epoch 117/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5248 - accuracy: 0.8485 - val_loss: 0.9968 - val_accuracy: 0.5000
# Epoch 118/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5194 - accuracy: 0.8636 - val_loss: 0.9960 - val_accuracy: 0.5455
# Epoch 119/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5131 - accuracy: 0.8485 - val_loss: 1.0176 - val_accuracy: 0.5000
# Epoch 120/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5085 - accuracy: 0.8485 - val_loss: 1.0079 - val_accuracy: 0.5455
# Epoch 121/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5054 - accuracy: 0.8636 - val_loss: 0.9976 - val_accuracy: 0.5455
# Epoch 122/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4976 - accuracy: 0.8485 - val_loss: 1.0063 - val_accuracy: 0.5455
# Epoch 123/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4941 - accuracy: 0.8485 - val_loss: 1.0079 - val_accuracy: 0.5000
# Epoch 124/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4953 - accuracy: 0.8485 - val_loss: 0.9801 - val_accuracy: 0.6364
# Epoch 125/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4864 - accuracy: 0.8333 - val_loss: 1.0111 - val_accuracy: 0.5455
# Epoch 126/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4823 - accuracy: 0.8636 - val_loss: 1.0263 - val_accuracy: 0.5455
# Epoch 127/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4799 - accuracy: 0.8636 - val_loss: 1.0312 - val_accuracy: 0.5455
# Epoch 128/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4764 - accuracy: 0.8485 - val_loss: 1.0253 - val_accuracy: 0.5909
# Epoch 129/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4667 - accuracy: 0.8788 - val_loss: 1.0274 - val_accuracy: 0.5455
# Epoch 130/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4635 - accuracy: 0.8636 - val_loss: 1.0225 - val_accuracy: 0.5455
# Epoch 131/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4609 - accuracy: 0.8485 - val_loss: 1.0279 - val_accuracy: 0.5455
# Epoch 132/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4569 - accuracy: 0.8788 - val_loss: 1.0193 - val_accuracy: 0.5000
# Epoch 133/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4508 - accuracy: 0.8333 - val_loss: 1.0118 - val_accuracy: 0.5909
# Epoch 134/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4481 - accuracy: 0.8788 - val_loss: 1.0114 - val_accuracy: 0.5909
# Epoch 135/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4421 - accuracy: 0.8485 - val_loss: 1.0203 - val_accuracy: 0.5909
# Epoch 136/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4381 - accuracy: 0.8636 - val_loss: 1.0289 - val_accuracy: 0.5909
# Epoch 137/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4325 - accuracy: 0.8636 - val_loss: 1.0189 - val_accuracy: 0.5909
# Epoch 138/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4347 - accuracy: 0.8636 - val_loss: 1.0228 - val_accuracy: 0.5909
# Epoch 139/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4260 - accuracy: 0.8788 - val_loss: 1.0162 - val_accuracy: 0.5455
# Epoch 140/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4286 - accuracy: 0.8636 - val_loss: 1.0423 - val_accuracy: 0.5909
# Epoch 141/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4268 - accuracy: 0.8636 - val_loss: 1.0329 - val_accuracy: 0.5909
# Epoch 142/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4170 - accuracy: 0.8788 - val_loss: 1.0271 - val_accuracy: 0.5909
# Epoch 143/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4114 - accuracy: 0.8485 - val_loss: 1.0494 - val_accuracy: 0.5455
# Epoch 144/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4110 - accuracy: 0.8636 - val_loss: 1.0465 - val_accuracy: 0.5909
# Epoch 145/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4093 - accuracy: 0.8788 - val_loss: 1.0409 - val_accuracy: 0.5455
# Epoch 146/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4084 - accuracy: 0.8636 - val_loss: 1.0639 - val_accuracy: 0.5455
# Epoch 147/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4039 - accuracy: 0.8788 - val_loss: 1.0445 - val_accuracy: 0.5000
# Epoch 148/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3975 - accuracy: 0.8788 - val_loss: 1.0598 - val_accuracy: 0.5455
# Epoch 149/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3967 - accuracy: 0.8939 - val_loss: 1.0222 - val_accuracy: 0.5909
# Epoch 150/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3916 - accuracy: 0.8636 - val_loss: 1.0436 - val_accuracy: 0.5455
# Epoch 151/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3848 - accuracy: 0.8788 - val_loss: 1.0340 - val_accuracy: 0.5909
# Epoch 152/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3851 - accuracy: 0.8788 - val_loss: 1.0564 - val_accuracy: 0.5455
# Epoch 153/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3844 - accuracy: 0.8939 - val_loss: 1.0227 - val_accuracy: 0.5455
# Epoch 154/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3902 - accuracy: 0.8636 - val_loss: 1.0313 - val_accuracy: 0.5909
# Epoch 155/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3812 - accuracy: 0.8788 - val_loss: 1.0066 - val_accuracy: 0.6364
# Epoch 156/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3817 - accuracy: 0.8485 - val_loss: 1.0645 - val_accuracy: 0.5455
# Epoch 157/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3701 - accuracy: 0.8788 - val_loss: 1.0734 - val_accuracy: 0.5455
# Epoch 158/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3673 - accuracy: 0.8788 - val_loss: 1.1165 - val_accuracy: 0.5000
# Epoch 159/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3708 - accuracy: 0.8788 - val_loss: 1.0860 - val_accuracy: 0.5455
# Epoch 160/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3605 - accuracy: 0.8788 - val_loss: 1.0666 - val_accuracy: 0.5455
# Epoch 161/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3628 - accuracy: 0.8788 - val_loss: 1.0920 - val_accuracy: 0.5909
# Epoch 162/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3578 - accuracy: 0.8788 - val_loss: 1.0283 - val_accuracy: 0.5909
# Epoch 163/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3654 - accuracy: 0.8485 - val_loss: 1.0609 - val_accuracy: 0.5909
# Epoch 164/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3459 - accuracy: 0.8788 - val_loss: 1.0839 - val_accuracy: 0.5909
# Epoch 165/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3463 - accuracy: 0.8939 - val_loss: 1.1065 - val_accuracy: 0.5455
# Epoch 166/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3505 - accuracy: 0.8788 - val_loss: 1.0796 - val_accuracy: 0.5455
# Epoch 167/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3449 - accuracy: 0.8939 - val_loss: 1.0944 - val_accuracy: 0.5000
# Epoch 168/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3410 - accuracy: 0.8939 - val_loss: 1.1232 - val_accuracy: 0.5455
# Epoch 169/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3359 - accuracy: 0.8939 - val_loss: 1.0869 - val_accuracy: 0.5455
# Epoch 170/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3308 - accuracy: 0.8939 - val_loss: 1.1050 - val_accuracy: 0.5000
# Epoch 171/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3286 - accuracy: 0.8939 - val_loss: 1.0926 - val_accuracy: 0.5455
# Epoch 172/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3312 - accuracy: 0.8788 - val_loss: 1.1057 - val_accuracy: 0.5000
# Epoch 173/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3238 - accuracy: 0.8939 - val_loss: 1.0930 - val_accuracy: 0.5455
# Epoch 174/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3199 - accuracy: 0.8788 - val_loss: 1.1154 - val_accuracy: 0.5000
# Epoch 175/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3176 - accuracy: 0.8939 - val_loss: 1.0892 - val_accuracy: 0.5455
# Epoch 176/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3151 - accuracy: 0.8788 - val_loss: 1.1322 - val_accuracy: 0.5000
# Epoch 177/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3116 - accuracy: 0.9091 - val_loss: 1.0953 - val_accuracy: 0.5455
# Epoch 178/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3101 - accuracy: 0.8939 - val_loss: 1.1317 - val_accuracy: 0.5455
# Epoch 179/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3097 - accuracy: 0.9091 - val_loss: 1.0670 - val_accuracy: 0.6364
# Epoch 180/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3099 - accuracy: 0.8939 - val_loss: 1.1032 - val_accuracy: 0.5000
# Epoch 181/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2980 - accuracy: 0.9242 - val_loss: 1.0984 - val_accuracy: 0.5455
# Epoch 182/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2994 - accuracy: 0.8939 - val_loss: 1.1125 - val_accuracy: 0.5909
# Epoch 183/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2975 - accuracy: 0.9091 - val_loss: 1.1386 - val_accuracy: 0.5000
# Epoch 184/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2952 - accuracy: 0.9091 - val_loss: 1.1436 - val_accuracy: 0.5000
# Epoch 185/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2940 - accuracy: 0.9091 - val_loss: 1.1544 - val_accuracy: 0.5000
# Epoch 186/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2971 - accuracy: 0.9091 - val_loss: 1.1722 - val_accuracy: 0.5000
# Epoch 187/300
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2948 - accuracy: 0.9091 - val_loss: 1.1609 - val_accuracy: 0.5000
# Epoch 188/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2844 - accuracy: 0.9242 - val_loss: 1.1329 - val_accuracy: 0.5455
# Epoch 189/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2830 - accuracy: 0.9242 - val_loss: 1.1420 - val_accuracy: 0.5909
# Epoch 190/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2802 - accuracy: 0.9242 - val_loss: 1.1183 - val_accuracy: 0.5909
# Epoch 191/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2792 - accuracy: 0.9242 - val_loss: 1.1129 - val_accuracy: 0.5909
# Epoch 192/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2784 - accuracy: 0.9091 - val_loss: 1.1854 - val_accuracy: 0.4545
# Epoch 193/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2759 - accuracy: 0.9242 - val_loss: 1.1496 - val_accuracy: 0.5455
# Epoch 194/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2725 - accuracy: 0.9091 - val_loss: 1.1502 - val_accuracy: 0.5455
# Epoch 195/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2657 - accuracy: 0.9242 - val_loss: 1.1525 - val_accuracy: 0.5455
# Epoch 196/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2643 - accuracy: 0.9242 - val_loss: 1.1675 - val_accuracy: 0.5000
# Epoch 197/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2675 - accuracy: 0.9545 - val_loss: 1.1359 - val_accuracy: 0.5455
# Epoch 198/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2604 - accuracy: 0.9394 - val_loss: 1.1692 - val_accuracy: 0.5455
# Epoch 199/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2622 - accuracy: 0.9394 - val_loss: 1.1041 - val_accuracy: 0.6364
# Epoch 200/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2783 - accuracy: 0.9091 - val_loss: 1.1632 - val_accuracy: 0.5455
# Epoch 201/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2560 - accuracy: 0.9242 - val_loss: 1.1794 - val_accuracy: 0.5455
# Epoch 202/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2570 - accuracy: 0.9242 - val_loss: 1.2128 - val_accuracy: 0.5000
# Epoch 203/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2500 - accuracy: 0.9394 - val_loss: 1.1987 - val_accuracy: 0.5000
# Epoch 204/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2503 - accuracy: 0.9545 - val_loss: 1.2005 - val_accuracy: 0.5000
# Epoch 205/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2430 - accuracy: 0.9545 - val_loss: 1.2131 - val_accuracy: 0.5000
# Epoch 206/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2437 - accuracy: 0.9394 - val_loss: 1.1960 - val_accuracy: 0.5455
# Epoch 207/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2479 - accuracy: 0.9545 - val_loss: 1.1857 - val_accuracy: 0.5455
# Epoch 208/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2470 - accuracy: 0.9394 - val_loss: 1.1375 - val_accuracy: 0.6364
# Epoch 209/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2453 - accuracy: 0.9242 - val_loss: 1.1764 - val_accuracy: 0.5909
# Epoch 210/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2335 - accuracy: 0.9242 - val_loss: 1.2234 - val_accuracy: 0.5000
# Epoch 211/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2386 - accuracy: 0.9545 - val_loss: 1.2869 - val_accuracy: 0.5000
# Epoch 212/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2400 - accuracy: 0.9545 - val_loss: 1.2668 - val_accuracy: 0.5000
# Epoch 213/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2302 - accuracy: 0.9394 - val_loss: 1.2115 - val_accuracy: 0.5000
# Epoch 214/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2316 - accuracy: 0.9545 - val_loss: 1.1737 - val_accuracy: 0.5455
# Epoch 215/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2308 - accuracy: 0.9242 - val_loss: 1.2047 - val_accuracy: 0.5455
# Epoch 216/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2220 - accuracy: 0.9394 - val_loss: 1.2070 - val_accuracy: 0.5455
# Epoch 217/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2330 - accuracy: 0.9394 - val_loss: 1.2071 - val_accuracy: 0.5909
# Epoch 218/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2248 - accuracy: 0.9394 - val_loss: 1.2327 - val_accuracy: 0.5000
# Epoch 219/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2181 - accuracy: 0.9394 - val_loss: 1.2092 - val_accuracy: 0.5909
# Epoch 220/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2218 - accuracy: 0.9394 - val_loss: 1.2101 - val_accuracy: 0.5909
# Epoch 221/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2116 - accuracy: 0.9394 - val_loss: 1.2345 - val_accuracy: 0.5455
# Epoch 222/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2168 - accuracy: 0.9394 - val_loss: 1.2458 - val_accuracy: 0.5000
# Epoch 223/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2176 - accuracy: 0.9394 - val_loss: 1.2615 - val_accuracy: 0.4545
# Epoch 224/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2137 - accuracy: 0.9394 - val_loss: 1.2947 - val_accuracy: 0.5000
# Epoch 225/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2144 - accuracy: 0.9545 - val_loss: 1.2743 - val_accuracy: 0.5455
# Epoch 226/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2089 - accuracy: 0.9394 - val_loss: 1.2627 - val_accuracy: 0.5909
# Epoch 227/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2097 - accuracy: 0.9545 - val_loss: 1.2869 - val_accuracy: 0.5000
# Epoch 228/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2037 - accuracy: 0.9545 - val_loss: 1.2807 - val_accuracy: 0.5455
# Epoch 229/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2071 - accuracy: 0.9394 - val_loss: 1.2559 - val_accuracy: 0.5455
# Epoch 230/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2034 - accuracy: 0.9545 - val_loss: 1.1882 - val_accuracy: 0.5455
# Epoch 231/300
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2106 - accuracy: 0.9091 - val_loss: 1.2787 - val_accuracy: 0.5455
# Epoch 232/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1975 - accuracy: 0.9394 - val_loss: 1.3159 - val_accuracy: 0.5000
# Epoch 233/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2086 - accuracy: 0.9545 - val_loss: 1.2983 - val_accuracy: 0.5000
# Epoch 234/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1995 - accuracy: 0.9545 - val_loss: 1.3102 - val_accuracy: 0.4545
# Epoch 235/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1953 - accuracy: 0.9545 - val_loss: 1.2260 - val_accuracy: 0.5455
# Epoch 236/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2112 - accuracy: 0.9242 - val_loss: 1.3408 - val_accuracy: 0.4545
# Epoch 237/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1960 - accuracy: 0.9545 - val_loss: 1.2941 - val_accuracy: 0.5455
# Epoch 238/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1932 - accuracy: 0.9394 - val_loss: 1.3400 - val_accuracy: 0.4545
# Epoch 239/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1904 - accuracy: 0.9545 - val_loss: 1.3172 - val_accuracy: 0.5000
# Epoch 240/300
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1888 - accuracy: 0.9545 - val_loss: 1.3018 - val_accuracy: 0.5455
# Epoch 241/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1850 - accuracy: 0.9545 - val_loss: 1.2946 - val_accuracy: 0.5455
# Epoch 242/300
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1855 - accuracy: 0.9545 - val_loss: 1.2767 - val_accuracy: 0.5455
# Epoch 243/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1867 - accuracy: 0.9545 - val_loss: 1.2857 - val_accuracy: 0.5909
# Epoch 244/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1841 - accuracy: 0.9545 - val_loss: 1.3211 - val_accuracy: 0.5909
# Epoch 245/300
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1846 - accuracy: 0.9394 - val_loss: 1.3328 - val_accuracy: 0.5000
# Epoch 246/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1844 - accuracy: 0.9394 - val_loss: 1.3648 - val_accuracy: 0.5000
# Epoch 247/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1792 - accuracy: 0.9545 - val_loss: 1.3341 - val_accuracy: 0.5000
# Epoch 248/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1778 - accuracy: 0.9545 - val_loss: 1.3089 - val_accuracy: 0.5455
# Epoch 249/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1723 - accuracy: 0.9545 - val_loss: 1.3025 - val_accuracy: 0.5909
# Epoch 250/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1782 - accuracy: 0.9545 - val_loss: 1.3083 - val_accuracy: 0.5455
# Epoch 251/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1749 - accuracy: 0.9394 - val_loss: 1.3368 - val_accuracy: 0.5000
# Epoch 252/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1733 - accuracy: 0.9545 - val_loss: 1.3072 - val_accuracy: 0.5455
# Epoch 253/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1684 - accuracy: 0.9545 - val_loss: 1.3304 - val_accuracy: 0.5455
# Epoch 254/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1714 - accuracy: 0.9394 - val_loss: 1.3662 - val_accuracy: 0.5455
# Epoch 255/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1676 - accuracy: 0.9697 - val_loss: 1.3618 - val_accuracy: 0.5000
# Epoch 256/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1733 - accuracy: 0.9545 - val_loss: 1.3448 - val_accuracy: 0.5000
# Epoch 257/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1693 - accuracy: 0.9545 - val_loss: 1.3308 - val_accuracy: 0.5909
# Epoch 258/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1703 - accuracy: 0.9545 - val_loss: 1.2476 - val_accuracy: 0.5455
# Epoch 259/300
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1734 - accuracy: 0.9242 - val_loss: 1.3534 - val_accuracy: 0.5000
# Epoch 260/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1639 - accuracy: 0.9697 - val_loss: 1.3440 - val_accuracy: 0.5455
# Epoch 261/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1647 - accuracy: 0.9545 - val_loss: 1.3755 - val_accuracy: 0.5455
# Epoch 262/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1592 - accuracy: 0.9697 - val_loss: 1.3440 - val_accuracy: 0.5455
# Epoch 263/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1563 - accuracy: 0.9697 - val_loss: 1.3606 - val_accuracy: 0.5455
# Epoch 264/300
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1603 - accuracy: 0.9697 - val_loss: 1.2891 - val_accuracy: 0.5909
# Epoch 265/300
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1654 - accuracy: 0.9545 - val_loss: 1.3533 - val_accuracy: 0.5455
# Epoch 266/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1581 - accuracy: 0.9545 - val_loss: 1.3819 - val_accuracy: 0.5000
# Epoch 267/300
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1584 - accuracy: 0.9545 - val_loss: 1.4168 - val_accuracy: 0.4545
# Epoch 268/300
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1502 - accuracy: 0.9697 - val_loss: 1.3863 - val_accuracy: 0.5455
# Epoch 269/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1543 - accuracy: 0.9697 - val_loss: 1.3525 - val_accuracy: 0.5455
# Epoch 270/300
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1488 - accuracy: 0.9697 - val_loss: 1.4776 - val_accuracy: 0.4545
# Epoch 271/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1601 - accuracy: 0.9697 - val_loss: 1.4246 - val_accuracy: 0.5000
# Epoch 272/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1469 - accuracy: 0.9697 - val_loss: 1.4374 - val_accuracy: 0.5000
# Epoch 273/300
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1478 - accuracy: 0.9697 - val_loss: 1.3050 - val_accuracy: 0.5455
# Epoch 274/300
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1572 - accuracy: 0.9394 - val_loss: 1.3788 - val_accuracy: 0.5455
# Epoch 275/300
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1456 - accuracy: 0.9545 - val_loss: 1.4189 - val_accuracy: 0.5000
# Epoch 276/300
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1431 - accuracy: 0.9697 - val_loss: 1.4133 - val_accuracy: 0.5000
# Epoch 277/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1475 - accuracy: 0.9697 - val_loss: 1.4375 - val_accuracy: 0.5000
# Epoch 278/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1420 - accuracy: 0.9697 - val_loss: 1.4563 - val_accuracy: 0.5455
# Epoch 279/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1456 - accuracy: 0.9697 - val_loss: 1.4143 - val_accuracy: 0.5909
# Epoch 280/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1420 - accuracy: 0.9697 - val_loss: 1.4434 - val_accuracy: 0.5909
# Epoch 281/300
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1421 - accuracy: 0.9697 - val_loss: 1.4236 - val_accuracy: 0.5909
# Epoch 282/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1453 - accuracy: 0.9545 - val_loss: 1.4418 - val_accuracy: 0.5909
# Epoch 283/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1385 - accuracy: 0.9697 - val_loss: 1.4023 - val_accuracy: 0.5455
# Epoch 284/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1366 - accuracy: 0.9697 - val_loss: 1.4318 - val_accuracy: 0.5000
# Epoch 285/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1348 - accuracy: 0.9697 - val_loss: 1.3987 - val_accuracy: 0.5455
# Epoch 286/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1345 - accuracy: 0.9545 - val_loss: 1.4334 - val_accuracy: 0.5000
# Epoch 287/300
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1379 - accuracy: 0.9697 - val_loss: 1.4657 - val_accuracy: 0.5000
# Epoch 288/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1342 - accuracy: 0.9697 - val_loss: 1.5150 - val_accuracy: 0.5000
# Epoch 289/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1429 - accuracy: 0.9697 - val_loss: 1.4806 - val_accuracy: 0.5000
# Epoch 290/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1344 - accuracy: 0.9697 - val_loss: 1.4628 - val_accuracy: 0.5000
# Epoch 291/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1292 - accuracy: 0.9697 - val_loss: 1.4861 - val_accuracy: 0.5000
# Epoch 292/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1335 - accuracy: 0.9697 - val_loss: 1.4454 - val_accuracy: 0.5455
# Epoch 293/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1291 - accuracy: 0.9697 - val_loss: 1.5295 - val_accuracy: 0.5000
# Epoch 294/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1326 - accuracy: 0.9697 - val_loss: 1.4627 - val_accuracy: 0.5455
# Epoch 295/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1263 - accuracy: 0.9697 - val_loss: 1.4747 - val_accuracy: 0.5000
# Epoch 296/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1276 - accuracy: 0.9697 - val_loss: 1.4528 - val_accuracy: 0.5455
# Epoch 297/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1228 - accuracy: 0.9848 - val_loss: 1.4785 - val_accuracy: 0.5000
# Epoch 298/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1240 - accuracy: 0.9697 - val_loss: 1.4585 - val_accuracy: 0.5455
# Epoch 299/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1251 - accuracy: 0.9697 - val_loss: 1.5497 - val_accuracy: 0.5000
# Epoch 300/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1318 - accuracy: 0.9697 - val_loss: 1.5160 - val_accuracy: 0.5000

# %%
# Save keras model to ONNX file 

from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(keras_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
# Submit keras model: 

#-- Generate predicted y values
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=keras_model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                           custom_metadata={'team': '5'})
# Out:
# 3/3 [==============================] - 0s 5ms/step
# Insert search tags to help users find your model (optional): initial model
# Provide any useful notes about your model (optional): initial model
#
# Your model has been submitted as model version 550
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# ## Final 3 Models

# %% [markdown]
# ### Set up

# %%
# Set up preprocessing

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# We create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.drop(['Country or region', 'name', 'region', 'sub-region'], axis=1)
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['region', 'sub-region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %%
# Write function to transform data with preprocessor

def preprocessor(data):
    data.drop(['Country or region', 'name'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (88, 26)

# %% [markdown]
# ### Model 1.2: Random Forest Classifier
# Increasing the max depth in the random forest model improved the F1 score from 0.44 to 0.52.

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=300, max_depth=10)
model.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 1.0

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from sklearn.ensemble import RandomForestClassifier

model_2 = RandomForestClassifier(n_estimators=200, max_depth=10)
model_2.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model_2.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 1.0

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model_2, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this World Happiness Classification Playground -- make sure to update the apiurl for new competition deployments
# apiurl="https://e2w6gh3id1.execute-api.us-east-2.amazonaws.com/prod/m"
apiurl = 'https://e2w6gh3id1.execute-api.us-east-2.amazonaws.com/prod/m'

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip",
                           custom_metadata={'team': '5'})
# Out:
# Insert search tags to help users find your model (optional): random forest
# Provide any useful notes about your model (optional): random forest with max depth = 10
#
# Your model has been submitted as model version 232
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# ### Model 2.2: Gradient Boosting Classifier
#
# Unlike the random forest classifier, toggling the max depth only marginally increases prediction accuracy.

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

#Example code to fit model:
model = GradientBoostingClassifier(n_estimators=150, learning_rate=1.0,
    max_depth=10, random_state=0).fit(preprocessor(X_train), y_train_labels)
model.score(preprocessor(X_train), y_train_labels)

# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values 
prediction_labels = model.predict(preprocessor(X_test))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                                 custom_metadata={'team': '5'})
# Out:
# Insert search tags to help users find your model (optional): team 5
# Provide any useful notes about your model (optional): max depth = 10
#
# Your model has been submitted as model version 235
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# ### Model 3.2: Original Neural Network
#
# Tweaking the batch size from 15 to 30, and keeping the number of epochs constant, improved the F1 score from 0.34 to 0.43.

# %%
# Or you can experiment with deep learning models: 
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

feature_count=preprocessor(X_train).shape[1] #count features in input data

keras_model = Sequential()
keras_model.add(Dense(128, input_dim=feature_count, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(32, activation='relu'))

keras_model.add(Dense(5, activation='softmax')) 
                                            
# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
keras_model.fit(preprocessor(X_train), y_train, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 30, 
               epochs = 300, validation_split=0.25)
# Out:
# Epoch 1/300
# 3/3 [==============================] - 1s 130ms/step - loss: 1.6078 - accuracy: 0.2424 - val_loss: 1.6271 - val_accuracy: 0.0909
# Epoch 2/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.6018 - accuracy: 0.2424 - val_loss: 1.6224 - val_accuracy: 0.0455
# Epoch 3/300
# 3/3 [==============================] - 0s 13ms/step - loss: 1.5952 - accuracy: 0.1970 - val_loss: 1.6198 - val_accuracy: 0.0455
# Epoch 4/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.5903 - accuracy: 0.2424 - val_loss: 1.6175 - val_accuracy: 0.0455
# Epoch 5/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.5837 - accuracy: 0.2576 - val_loss: 1.6162 - val_accuracy: 0.0455
# Epoch 6/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.5781 - accuracy: 0.2727 - val_loss: 1.6132 - val_accuracy: 0.0455
# Epoch 7/300
# 3/3 [==============================] - 0s 24ms/step - loss: 1.5728 - accuracy: 0.2879 - val_loss: 1.6102 - val_accuracy: 0.0909
# Epoch 8/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.5680 - accuracy: 0.2879 - val_loss: 1.6074 - val_accuracy: 0.1364
# Epoch 9/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.5626 - accuracy: 0.2879 - val_loss: 1.6040 - val_accuracy: 0.1364
# Epoch 10/300
# 3/3 [==============================] - 0s 24ms/step - loss: 1.5576 - accuracy: 0.2879 - val_loss: 1.6019 - val_accuracy: 0.1364
# Epoch 11/300
# 3/3 [==============================] - 0s 13ms/step - loss: 1.5540 - accuracy: 0.3030 - val_loss: 1.6000 - val_accuracy: 0.1364
# Epoch 12/300
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5484 - accuracy: 0.3030 - val_loss: 1.5992 - val_accuracy: 0.1364
# Epoch 13/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.5430 - accuracy: 0.3030 - val_loss: 1.5987 - val_accuracy: 0.1818
# Epoch 14/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.5378 - accuracy: 0.3030 - val_loss: 1.5960 - val_accuracy: 0.1818
# Epoch 15/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.5324 - accuracy: 0.3030 - val_loss: 1.5919 - val_accuracy: 0.1818
# Epoch 16/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.5280 - accuracy: 0.3030 - val_loss: 1.5893 - val_accuracy: 0.1818
# Epoch 17/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.5231 - accuracy: 0.3030 - val_loss: 1.5857 - val_accuracy: 0.1818
# Epoch 18/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.5179 - accuracy: 0.3182 - val_loss: 1.5834 - val_accuracy: 0.1818
# Epoch 19/300
# 3/3 [==============================] - 0s 19ms/step - loss: 1.5131 - accuracy: 0.3030 - val_loss: 1.5822 - val_accuracy: 0.1818
# Epoch 20/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.5079 - accuracy: 0.3030 - val_loss: 1.5815 - val_accuracy: 0.1818
# Epoch 21/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.5033 - accuracy: 0.2879 - val_loss: 1.5799 - val_accuracy: 0.1818
# Epoch 22/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.4982 - accuracy: 0.3030 - val_loss: 1.5774 - val_accuracy: 0.1818
# Epoch 23/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4931 - accuracy: 0.3030 - val_loss: 1.5754 - val_accuracy: 0.1818
# Epoch 24/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.4879 - accuracy: 0.3030 - val_loss: 1.5742 - val_accuracy: 0.1818
# Epoch 25/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.4826 - accuracy: 0.3030 - val_loss: 1.5720 - val_accuracy: 0.1818
# Epoch 26/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4777 - accuracy: 0.3182 - val_loss: 1.5676 - val_accuracy: 0.1818
# Epoch 27/300
# 3/3 [==============================] - 0s 13ms/step - loss: 1.4728 - accuracy: 0.3485 - val_loss: 1.5634 - val_accuracy: 0.1818
# Epoch 28/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.4676 - accuracy: 0.3485 - val_loss: 1.5601 - val_accuracy: 0.1818
# Epoch 29/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.4622 - accuracy: 0.3636 - val_loss: 1.5570 - val_accuracy: 0.1818
# Epoch 30/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4575 - accuracy: 0.3939 - val_loss: 1.5540 - val_accuracy: 0.1818
# Epoch 31/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.4523 - accuracy: 0.3939 - val_loss: 1.5500 - val_accuracy: 0.2273
# Epoch 32/300
# 3/3 [==============================] - 0s 13ms/step - loss: 1.4475 - accuracy: 0.4091 - val_loss: 1.5476 - val_accuracy: 0.2273
# Epoch 33/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4419 - accuracy: 0.4091 - val_loss: 1.5428 - val_accuracy: 0.2727
# Epoch 34/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.4347 - accuracy: 0.4394 - val_loss: 1.5398 - val_accuracy: 0.2727
# Epoch 35/300
# 3/3 [==============================] - 0s 13ms/step - loss: 1.4297 - accuracy: 0.4394 - val_loss: 1.5365 - val_accuracy: 0.2727
# Epoch 36/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.4249 - accuracy: 0.4394 - val_loss: 1.5352 - val_accuracy: 0.2727
# Epoch 37/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.4182 - accuracy: 0.4394 - val_loss: 1.5317 - val_accuracy: 0.2727
# Epoch 38/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4126 - accuracy: 0.4545 - val_loss: 1.5263 - val_accuracy: 0.2727
# Epoch 39/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.4066 - accuracy: 0.4545 - val_loss: 1.5213 - val_accuracy: 0.2727
# Epoch 40/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4013 - accuracy: 0.4545 - val_loss: 1.5155 - val_accuracy: 0.2727
# Epoch 41/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3957 - accuracy: 0.4545 - val_loss: 1.5097 - val_accuracy: 0.2727
# Epoch 42/300
# 3/3 [==============================] - 0s 13ms/step - loss: 1.3902 - accuracy: 0.4545 - val_loss: 1.5065 - val_accuracy: 0.2727
# Epoch 43/300
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3852 - accuracy: 0.4545 - val_loss: 1.5054 - val_accuracy: 0.2727
# Epoch 44/300
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3783 - accuracy: 0.4545 - val_loss: 1.5018 - val_accuracy: 0.2727
# Epoch 45/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3724 - accuracy: 0.4545 - val_loss: 1.4994 - val_accuracy: 0.2727
# Epoch 46/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3658 - accuracy: 0.4545 - val_loss: 1.4950 - val_accuracy: 0.2727
# Epoch 47/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3595 - accuracy: 0.4545 - val_loss: 1.4904 - val_accuracy: 0.2727
# Epoch 48/300
# 3/3 [==============================] - 0s 25ms/step - loss: 1.3532 - accuracy: 0.4545 - val_loss: 1.4882 - val_accuracy: 0.2727
# Epoch 49/300
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3476 - accuracy: 0.4545 - val_loss: 1.4819 - val_accuracy: 0.2727
# Epoch 50/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3420 - accuracy: 0.4545 - val_loss: 1.4791 - val_accuracy: 0.2727
# Epoch 51/300
# 3/3 [==============================] - 0s 27ms/step - loss: 1.3364 - accuracy: 0.4545 - val_loss: 1.4738 - val_accuracy: 0.3182
# Epoch 52/300
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3304 - accuracy: 0.4848 - val_loss: 1.4692 - val_accuracy: 0.3182
# Epoch 53/300
# 3/3 [==============================] - 0s 21ms/step - loss: 1.3247 - accuracy: 0.4848 - val_loss: 1.4637 - val_accuracy: 0.3182
# Epoch 54/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3174 - accuracy: 0.5152 - val_loss: 1.4620 - val_accuracy: 0.3182
# Epoch 55/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3107 - accuracy: 0.5152 - val_loss: 1.4568 - val_accuracy: 0.3182
# Epoch 56/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3043 - accuracy: 0.5152 - val_loss: 1.4537 - val_accuracy: 0.3182
# Epoch 57/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.2981 - accuracy: 0.5152 - val_loss: 1.4498 - val_accuracy: 0.3182
# Epoch 58/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.2923 - accuracy: 0.5152 - val_loss: 1.4471 - val_accuracy: 0.3182
# Epoch 59/300
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2859 - accuracy: 0.5152 - val_loss: 1.4397 - val_accuracy: 0.3182
# Epoch 60/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2782 - accuracy: 0.5152 - val_loss: 1.4347 - val_accuracy: 0.3636
# Epoch 61/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2712 - accuracy: 0.5152 - val_loss: 1.4283 - val_accuracy: 0.3636
# Epoch 62/300
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2646 - accuracy: 0.5455 - val_loss: 1.4254 - val_accuracy: 0.3636
# Epoch 63/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2587 - accuracy: 0.5303 - val_loss: 1.4243 - val_accuracy: 0.3636
# Epoch 64/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2519 - accuracy: 0.5152 - val_loss: 1.4186 - val_accuracy: 0.3636
# Epoch 65/300
# 3/3 [==============================] - 0s 21ms/step - loss: 1.2449 - accuracy: 0.5303 - val_loss: 1.4101 - val_accuracy: 0.3636
# Epoch 66/300
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2391 - accuracy: 0.5606 - val_loss: 1.4071 - val_accuracy: 0.3636
# Epoch 67/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2318 - accuracy: 0.5455 - val_loss: 1.3982 - val_accuracy: 0.3636
# Epoch 68/300
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2255 - accuracy: 0.5758 - val_loss: 1.3914 - val_accuracy: 0.3636
# Epoch 69/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2178 - accuracy: 0.5758 - val_loss: 1.3859 - val_accuracy: 0.3636
# Epoch 70/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2106 - accuracy: 0.5758 - val_loss: 1.3810 - val_accuracy: 0.3636
# Epoch 71/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.2042 - accuracy: 0.5909 - val_loss: 1.3750 - val_accuracy: 0.3636
# Epoch 72/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1977 - accuracy: 0.5909 - val_loss: 1.3706 - val_accuracy: 0.3636
# Epoch 73/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.1911 - accuracy: 0.5909 - val_loss: 1.3646 - val_accuracy: 0.3636
# Epoch 74/300
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1846 - accuracy: 0.5758 - val_loss: 1.3568 - val_accuracy: 0.3636
# Epoch 75/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1763 - accuracy: 0.6061 - val_loss: 1.3478 - val_accuracy: 0.3636
# Epoch 76/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1704 - accuracy: 0.6061 - val_loss: 1.3438 - val_accuracy: 0.3636
# Epoch 77/300
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1641 - accuracy: 0.6061 - val_loss: 1.3332 - val_accuracy: 0.4091
# Epoch 78/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1570 - accuracy: 0.6061 - val_loss: 1.3309 - val_accuracy: 0.4091
# Epoch 79/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1505 - accuracy: 0.6061 - val_loss: 1.3248 - val_accuracy: 0.4091
# Epoch 80/300
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1454 - accuracy: 0.6061 - val_loss: 1.3238 - val_accuracy: 0.4091
# Epoch 81/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1378 - accuracy: 0.6061 - val_loss: 1.3204 - val_accuracy: 0.4091
# Epoch 82/300
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1310 - accuracy: 0.6061 - val_loss: 1.3090 - val_accuracy: 0.4091
# Epoch 83/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.1258 - accuracy: 0.6061 - val_loss: 1.2993 - val_accuracy: 0.4091
# Epoch 84/300
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1188 - accuracy: 0.6061 - val_loss: 1.2947 - val_accuracy: 0.4091
# Epoch 85/300
# 3/3 [==============================] - 0s 20ms/step - loss: 1.1118 - accuracy: 0.6061 - val_loss: 1.2917 - val_accuracy: 0.4091
# Epoch 86/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.1052 - accuracy: 0.6061 - val_loss: 1.2840 - val_accuracy: 0.4091
# Epoch 87/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0990 - accuracy: 0.6061 - val_loss: 1.2805 - val_accuracy: 0.4091
# Epoch 88/300
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0927 - accuracy: 0.6061 - val_loss: 1.2762 - val_accuracy: 0.4091
# Epoch 89/300
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0867 - accuracy: 0.6061 - val_loss: 1.2768 - val_accuracy: 0.4091
# Epoch 90/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0809 - accuracy: 0.6061 - val_loss: 1.2750 - val_accuracy: 0.4091
# Epoch 91/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0755 - accuracy: 0.6061 - val_loss: 1.2667 - val_accuracy: 0.4091
# Epoch 92/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0678 - accuracy: 0.6061 - val_loss: 1.2642 - val_accuracy: 0.4091
# Epoch 93/300
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0615 - accuracy: 0.6061 - val_loss: 1.2602 - val_accuracy: 0.4091
# Epoch 94/300
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0561 - accuracy: 0.6061 - val_loss: 1.2512 - val_accuracy: 0.4091
# Epoch 95/300
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0499 - accuracy: 0.6061 - val_loss: 1.2484 - val_accuracy: 0.4091
# Epoch 96/300
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0439 - accuracy: 0.6061 - val_loss: 1.2419 - val_accuracy: 0.4091
# Epoch 97/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0378 - accuracy: 0.6061 - val_loss: 1.2376 - val_accuracy: 0.4091
# Epoch 98/300
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0328 - accuracy: 0.6061 - val_loss: 1.2412 - val_accuracy: 0.4091
# Epoch 99/300
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0288 - accuracy: 0.6061 - val_loss: 1.2346 - val_accuracy: 0.4091
# Epoch 100/300
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0225 - accuracy: 0.6061 - val_loss: 1.2306 - val_accuracy: 0.4091
# Epoch 101/300
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0172 - accuracy: 0.6061 - val_loss: 1.2219 - val_accuracy: 0.4091
# Epoch 102/300
# 3/3 [==============================] - 0s 28ms/step - loss: 1.0117 - accuracy: 0.6061 - val_loss: 1.2212 - val_accuracy: 0.4091
# Epoch 103/300
# 3/3 [==============================] - 0s 21ms/step - loss: 1.0064 - accuracy: 0.6061 - val_loss: 1.2070 - val_accuracy: 0.4091
# Epoch 104/300
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0011 - accuracy: 0.6061 - val_loss: 1.1992 - val_accuracy: 0.4091
# Epoch 105/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9949 - accuracy: 0.6061 - val_loss: 1.1996 - val_accuracy: 0.4091
# Epoch 106/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9899 - accuracy: 0.6061 - val_loss: 1.1972 - val_accuracy: 0.4091
# Epoch 107/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.9843 - accuracy: 0.6212 - val_loss: 1.1983 - val_accuracy: 0.4091
# Epoch 108/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.9798 - accuracy: 0.6061 - val_loss: 1.1923 - val_accuracy: 0.4091
# Epoch 109/300
# 3/3 [==============================] - 0s 24ms/step - loss: 0.9750 - accuracy: 0.6212 - val_loss: 1.1888 - val_accuracy: 0.4091
# Epoch 110/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9683 - accuracy: 0.6061 - val_loss: 1.1783 - val_accuracy: 0.4091
# Epoch 111/300
# 3/3 [==============================] - 0s 21ms/step - loss: 0.9658 - accuracy: 0.6212 - val_loss: 1.1824 - val_accuracy: 0.4091
# Epoch 112/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.9587 - accuracy: 0.6212 - val_loss: 1.1688 - val_accuracy: 0.4091
# Epoch 113/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.9530 - accuracy: 0.6364 - val_loss: 1.1600 - val_accuracy: 0.4091
# Epoch 114/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9487 - accuracy: 0.6364 - val_loss: 1.1477 - val_accuracy: 0.4091
# Epoch 115/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9422 - accuracy: 0.6364 - val_loss: 1.1450 - val_accuracy: 0.4091
# Epoch 116/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.9372 - accuracy: 0.6515 - val_loss: 1.1404 - val_accuracy: 0.4091
# Epoch 117/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.9323 - accuracy: 0.6667 - val_loss: 1.1338 - val_accuracy: 0.4091
# Epoch 118/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.9266 - accuracy: 0.6667 - val_loss: 1.1335 - val_accuracy: 0.4091
# Epoch 119/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.9213 - accuracy: 0.6818 - val_loss: 1.1318 - val_accuracy: 0.4091
# Epoch 120/300
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9163 - accuracy: 0.6667 - val_loss: 1.1314 - val_accuracy: 0.4091
# Epoch 121/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9122 - accuracy: 0.6667 - val_loss: 1.1327 - val_accuracy: 0.4091
# Epoch 122/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.9076 - accuracy: 0.6667 - val_loss: 1.1318 - val_accuracy: 0.4545
# Epoch 123/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.9030 - accuracy: 0.6667 - val_loss: 1.1197 - val_accuracy: 0.4545
# Epoch 124/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8978 - accuracy: 0.6818 - val_loss: 1.1131 - val_accuracy: 0.4545
# Epoch 125/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.8926 - accuracy: 0.6818 - val_loss: 1.0980 - val_accuracy: 0.5000
# Epoch 126/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.8870 - accuracy: 0.6970 - val_loss: 1.0972 - val_accuracy: 0.4545
# Epoch 127/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8821 - accuracy: 0.6818 - val_loss: 1.0888 - val_accuracy: 0.5000
# Epoch 128/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8769 - accuracy: 0.7121 - val_loss: 1.0846 - val_accuracy: 0.5000
# Epoch 129/300
# 3/3 [==============================] - 0s 26ms/step - loss: 0.8731 - accuracy: 0.6970 - val_loss: 1.0743 - val_accuracy: 0.5455
# Epoch 130/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8701 - accuracy: 0.7121 - val_loss: 1.0726 - val_accuracy: 0.5455
# Epoch 131/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8649 - accuracy: 0.7121 - val_loss: 1.0712 - val_accuracy: 0.5000
# Epoch 132/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8591 - accuracy: 0.7273 - val_loss: 1.0673 - val_accuracy: 0.5000
# Epoch 133/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8546 - accuracy: 0.7273 - val_loss: 1.0689 - val_accuracy: 0.5000
# Epoch 134/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8493 - accuracy: 0.7273 - val_loss: 1.0684 - val_accuracy: 0.5000
# Epoch 135/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.8454 - accuracy: 0.7121 - val_loss: 1.0687 - val_accuracy: 0.5000
# Epoch 136/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8396 - accuracy: 0.7273 - val_loss: 1.0603 - val_accuracy: 0.5000
# Epoch 137/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8350 - accuracy: 0.7424 - val_loss: 1.0549 - val_accuracy: 0.5000
# Epoch 138/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8302 - accuracy: 0.7273 - val_loss: 1.0545 - val_accuracy: 0.5000
# Epoch 139/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8260 - accuracy: 0.7273 - val_loss: 1.0547 - val_accuracy: 0.5000
# Epoch 140/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8220 - accuracy: 0.7273 - val_loss: 1.0466 - val_accuracy: 0.5455
# Epoch 141/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8174 - accuracy: 0.7576 - val_loss: 1.0471 - val_accuracy: 0.5455
# Epoch 142/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8126 - accuracy: 0.7424 - val_loss: 1.0397 - val_accuracy: 0.5455
# Epoch 143/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8081 - accuracy: 0.7576 - val_loss: 1.0408 - val_accuracy: 0.5455
# Epoch 144/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.8029 - accuracy: 0.7424 - val_loss: 1.0262 - val_accuracy: 0.5909
# Epoch 145/300
# 3/3 [==============================] - 0s 23ms/step - loss: 0.8003 - accuracy: 0.7576 - val_loss: 1.0206 - val_accuracy: 0.5909
# Epoch 146/300
# 3/3 [==============================] - 0s 26ms/step - loss: 0.7966 - accuracy: 0.7424 - val_loss: 1.0141 - val_accuracy: 0.5455
# Epoch 147/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7901 - accuracy: 0.7576 - val_loss: 1.0169 - val_accuracy: 0.5455
# Epoch 148/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7851 - accuracy: 0.7576 - val_loss: 1.0170 - val_accuracy: 0.5455
# Epoch 149/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7807 - accuracy: 0.7576 - val_loss: 1.0251 - val_accuracy: 0.5455
# Epoch 150/300
# 3/3 [==============================] - 0s 21ms/step - loss: 0.7761 - accuracy: 0.7424 - val_loss: 1.0271 - val_accuracy: 0.5455
# Epoch 151/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7731 - accuracy: 0.7424 - val_loss: 1.0275 - val_accuracy: 0.5455
# Epoch 152/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7676 - accuracy: 0.7424 - val_loss: 1.0211 - val_accuracy: 0.5455
# Epoch 153/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.7627 - accuracy: 0.7576 - val_loss: 1.0142 - val_accuracy: 0.5455
# Epoch 154/300
# 3/3 [==============================] - 0s 26ms/step - loss: 0.7613 - accuracy: 0.7576 - val_loss: 1.0138 - val_accuracy: 0.5455
# Epoch 155/300
# 3/3 [==============================] - 0s 23ms/step - loss: 0.7548 - accuracy: 0.7576 - val_loss: 1.0004 - val_accuracy: 0.5455
# Epoch 156/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7506 - accuracy: 0.7576 - val_loss: 1.0054 - val_accuracy: 0.5455
# Epoch 157/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7485 - accuracy: 0.7424 - val_loss: 0.9934 - val_accuracy: 0.5455
# Epoch 158/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7442 - accuracy: 0.7727 - val_loss: 0.9860 - val_accuracy: 0.5455
# Epoch 159/300
# 3/3 [==============================] - 0s 24ms/step - loss: 0.7407 - accuracy: 0.7879 - val_loss: 0.9856 - val_accuracy: 0.5455
# Epoch 160/300
# 3/3 [==============================] - 0s 26ms/step - loss: 0.7371 - accuracy: 0.7727 - val_loss: 0.9810 - val_accuracy: 0.5455
# Epoch 161/300
# 3/3 [==============================] - 0s 27ms/step - loss: 0.7343 - accuracy: 0.7879 - val_loss: 0.9925 - val_accuracy: 0.5455
# Epoch 162/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.7289 - accuracy: 0.7576 - val_loss: 0.9777 - val_accuracy: 0.5455
# Epoch 163/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.7291 - accuracy: 0.7879 - val_loss: 0.9747 - val_accuracy: 0.5455
# Epoch 164/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7233 - accuracy: 0.8030 - val_loss: 0.9778 - val_accuracy: 0.5455
# Epoch 165/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7204 - accuracy: 0.7879 - val_loss: 0.9746 - val_accuracy: 0.5455
# Epoch 166/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.7152 - accuracy: 0.7879 - val_loss: 0.9870 - val_accuracy: 0.5455
# Epoch 167/300
# 3/3 [==============================] - 0s 23ms/step - loss: 0.7105 - accuracy: 0.7576 - val_loss: 0.9891 - val_accuracy: 0.5455
# Epoch 168/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.7058 - accuracy: 0.7727 - val_loss: 0.9753 - val_accuracy: 0.5455
# Epoch 169/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7010 - accuracy: 0.7727 - val_loss: 0.9847 - val_accuracy: 0.5455
# Epoch 170/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6986 - accuracy: 0.7727 - val_loss: 0.9750 - val_accuracy: 0.5455
# Epoch 171/300
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6953 - accuracy: 0.7879 - val_loss: 0.9753 - val_accuracy: 0.5455
# Epoch 172/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6924 - accuracy: 0.7879 - val_loss: 0.9769 - val_accuracy: 0.5455
# Epoch 173/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6869 - accuracy: 0.7879 - val_loss: 0.9697 - val_accuracy: 0.5455
# Epoch 174/300
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6824 - accuracy: 0.7879 - val_loss: 0.9695 - val_accuracy: 0.5455
# Epoch 175/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6795 - accuracy: 0.7879 - val_loss: 0.9773 - val_accuracy: 0.5455
# Epoch 176/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6769 - accuracy: 0.7879 - val_loss: 0.9655 - val_accuracy: 0.5455
# Epoch 177/300
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6742 - accuracy: 0.7879 - val_loss: 0.9744 - val_accuracy: 0.5455
# Epoch 178/300
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6732 - accuracy: 0.7879 - val_loss: 0.9746 - val_accuracy: 0.5455
# Epoch 179/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6700 - accuracy: 0.7879 - val_loss: 0.9672 - val_accuracy: 0.5455
# Epoch 180/300
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6639 - accuracy: 0.8182 - val_loss: 0.9681 - val_accuracy: 0.5455
# Epoch 181/300
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6609 - accuracy: 0.8182 - val_loss: 0.9706 - val_accuracy: 0.5455
# Epoch 182/300
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6583 - accuracy: 0.8030 - val_loss: 0.9542 - val_accuracy: 0.5455
# Epoch 183/300
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6531 - accuracy: 0.8333 - val_loss: 0.9470 - val_accuracy: 0.5455
# Epoch 184/300
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6500 - accuracy: 0.8636 - val_loss: 0.9509 - val_accuracy: 0.5455
# Epoch 185/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6447 - accuracy: 0.8485 - val_loss: 0.9441 - val_accuracy: 0.5455
# Epoch 186/300
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6435 - accuracy: 0.8333 - val_loss: 0.9392 - val_accuracy: 0.5455
# Epoch 187/300
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6397 - accuracy: 0.8333 - val_loss: 0.9354 - val_accuracy: 0.5455
# Epoch 188/300
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6375 - accuracy: 0.8485 - val_loss: 0.9330 - val_accuracy: 0.5455
# Epoch 189/300
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6350 - accuracy: 0.8485 - val_loss: 0.9336 - val_accuracy: 0.5909
# Epoch 190/300
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6327 - accuracy: 0.8636 - val_loss: 0.9396 - val_accuracy: 0.5455
# Epoch 191/300
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6289 - accuracy: 0.8636 - val_loss: 0.9292 - val_accuracy: 0.5909
# Epoch 192/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6290 - accuracy: 0.8485 - val_loss: 0.9316 - val_accuracy: 0.5909
# Epoch 193/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6249 - accuracy: 0.8788 - val_loss: 0.9215 - val_accuracy: 0.5909
# Epoch 194/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6216 - accuracy: 0.8636 - val_loss: 0.9105 - val_accuracy: 0.6364
# Epoch 195/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6228 - accuracy: 0.8788 - val_loss: 0.9139 - val_accuracy: 0.5909
# Epoch 196/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6152 - accuracy: 0.8788 - val_loss: 0.9275 - val_accuracy: 0.5455
# Epoch 197/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6081 - accuracy: 0.8636 - val_loss: 0.9249 - val_accuracy: 0.5455
# Epoch 198/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6061 - accuracy: 0.8485 - val_loss: 0.9262 - val_accuracy: 0.5455
# Epoch 199/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6024 - accuracy: 0.8485 - val_loss: 0.9271 - val_accuracy: 0.5909
# Epoch 200/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6012 - accuracy: 0.8788 - val_loss: 0.9130 - val_accuracy: 0.5455
# Epoch 201/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6003 - accuracy: 0.8636 - val_loss: 0.8976 - val_accuracy: 0.6364
# Epoch 202/300
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5998 - accuracy: 0.8636 - val_loss: 0.9038 - val_accuracy: 0.6364
# Epoch 203/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5951 - accuracy: 0.8636 - val_loss: 0.9007 - val_accuracy: 0.6364
# Epoch 204/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5949 - accuracy: 0.8788 - val_loss: 0.9042 - val_accuracy: 0.5909
# Epoch 205/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5892 - accuracy: 0.8788 - val_loss: 0.9026 - val_accuracy: 0.5455
# Epoch 206/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5851 - accuracy: 0.8636 - val_loss: 0.9096 - val_accuracy: 0.5455
# Epoch 207/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5801 - accuracy: 0.8636 - val_loss: 0.9073 - val_accuracy: 0.5455
# Epoch 208/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5782 - accuracy: 0.8636 - val_loss: 0.9148 - val_accuracy: 0.5455
# Epoch 209/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5754 - accuracy: 0.8636 - val_loss: 0.9239 - val_accuracy: 0.5455
# Epoch 210/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5719 - accuracy: 0.8939 - val_loss: 0.9368 - val_accuracy: 0.5455
# Epoch 211/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5716 - accuracy: 0.8636 - val_loss: 0.9484 - val_accuracy: 0.5455
# Epoch 212/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5681 - accuracy: 0.8636 - val_loss: 0.9480 - val_accuracy: 0.5455
# Epoch 213/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5656 - accuracy: 0.8636 - val_loss: 0.9373 - val_accuracy: 0.5455
# Epoch 214/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5613 - accuracy: 0.8788 - val_loss: 0.9241 - val_accuracy: 0.5455
# Epoch 215/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5576 - accuracy: 0.8636 - val_loss: 0.9242 - val_accuracy: 0.5909
# Epoch 216/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5552 - accuracy: 0.8788 - val_loss: 0.9212 - val_accuracy: 0.5909
# Epoch 217/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5529 - accuracy: 0.8788 - val_loss: 0.9125 - val_accuracy: 0.5909
# Epoch 218/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5495 - accuracy: 0.8788 - val_loss: 0.9090 - val_accuracy: 0.5909
# Epoch 219/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5508 - accuracy: 0.8636 - val_loss: 0.9151 - val_accuracy: 0.5909
# Epoch 220/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5471 - accuracy: 0.8788 - val_loss: 0.9358 - val_accuracy: 0.5909
# Epoch 221/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5425 - accuracy: 0.8788 - val_loss: 0.9176 - val_accuracy: 0.5909
# Epoch 222/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5394 - accuracy: 0.8788 - val_loss: 0.9120 - val_accuracy: 0.5909
# Epoch 223/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5365 - accuracy: 0.8788 - val_loss: 0.9046 - val_accuracy: 0.5909
# Epoch 224/300
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5354 - accuracy: 0.8788 - val_loss: 0.8960 - val_accuracy: 0.5909
# Epoch 225/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5379 - accuracy: 0.8636 - val_loss: 0.8976 - val_accuracy: 0.5909
# Epoch 226/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5289 - accuracy: 0.8636 - val_loss: 0.8973 - val_accuracy: 0.5909
# Epoch 227/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5265 - accuracy: 0.8636 - val_loss: 0.8975 - val_accuracy: 0.5909
# Epoch 228/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5230 - accuracy: 0.8788 - val_loss: 0.9024 - val_accuracy: 0.5455
# Epoch 229/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5220 - accuracy: 0.8788 - val_loss: 0.9003 - val_accuracy: 0.5909
# Epoch 230/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5194 - accuracy: 0.8788 - val_loss: 0.9026 - val_accuracy: 0.6364
# Epoch 231/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5177 - accuracy: 0.8788 - val_loss: 0.9035 - val_accuracy: 0.6364
# Epoch 232/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5149 - accuracy: 0.8939 - val_loss: 0.9062 - val_accuracy: 0.5909
# Epoch 233/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5108 - accuracy: 0.8788 - val_loss: 0.9101 - val_accuracy: 0.5455
# Epoch 234/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5105 - accuracy: 0.8788 - val_loss: 0.9201 - val_accuracy: 0.5455
# Epoch 235/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5067 - accuracy: 0.8939 - val_loss: 0.9317 - val_accuracy: 0.5909
# Epoch 236/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5051 - accuracy: 0.8788 - val_loss: 0.8986 - val_accuracy: 0.6364
# Epoch 237/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5011 - accuracy: 0.9091 - val_loss: 0.8959 - val_accuracy: 0.5909
# Epoch 238/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5008 - accuracy: 0.8788 - val_loss: 0.9073 - val_accuracy: 0.5455
# Epoch 239/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4978 - accuracy: 0.8788 - val_loss: 0.8957 - val_accuracy: 0.5455
# Epoch 240/300
# 3/3 [==============================] - 0s 30ms/step - loss: 0.4960 - accuracy: 0.8636 - val_loss: 0.8997 - val_accuracy: 0.5455
# Epoch 241/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4938 - accuracy: 0.8788 - val_loss: 0.8871 - val_accuracy: 0.6364
# Epoch 242/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4904 - accuracy: 0.8939 - val_loss: 0.9045 - val_accuracy: 0.5909
# Epoch 243/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4855 - accuracy: 0.8939 - val_loss: 0.9047 - val_accuracy: 0.5909
# Epoch 244/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4837 - accuracy: 0.8939 - val_loss: 0.9285 - val_accuracy: 0.5455
# Epoch 245/300
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4810 - accuracy: 0.8939 - val_loss: 0.9253 - val_accuracy: 0.5455
# Epoch 246/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4781 - accuracy: 0.8939 - val_loss: 0.9304 - val_accuracy: 0.5455
# Epoch 247/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4757 - accuracy: 0.8939 - val_loss: 0.9320 - val_accuracy: 0.5909
# Epoch 248/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4744 - accuracy: 0.8939 - val_loss: 0.9070 - val_accuracy: 0.5909
# Epoch 249/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4744 - accuracy: 0.8788 - val_loss: 0.9335 - val_accuracy: 0.5455
# Epoch 250/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4707 - accuracy: 0.9091 - val_loss: 0.9347 - val_accuracy: 0.5909
# Epoch 251/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4687 - accuracy: 0.9091 - val_loss: 0.9387 - val_accuracy: 0.5455
# Epoch 252/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4653 - accuracy: 0.9091 - val_loss: 0.9131 - val_accuracy: 0.6364
# Epoch 253/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4672 - accuracy: 0.8939 - val_loss: 0.9158 - val_accuracy: 0.5909
# Epoch 254/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4610 - accuracy: 0.9091 - val_loss: 0.9256 - val_accuracy: 0.5909
# Epoch 255/300
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4586 - accuracy: 0.9091 - val_loss: 0.9210 - val_accuracy: 0.5909
# Epoch 256/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4581 - accuracy: 0.9091 - val_loss: 0.9081 - val_accuracy: 0.6364
# Epoch 257/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4567 - accuracy: 0.9091 - val_loss: 0.9130 - val_accuracy: 0.5909
# Epoch 258/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4512 - accuracy: 0.9091 - val_loss: 0.9190 - val_accuracy: 0.5909
# Epoch 259/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4476 - accuracy: 0.9091 - val_loss: 0.9087 - val_accuracy: 0.6364
# Epoch 260/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4464 - accuracy: 0.9091 - val_loss: 0.9182 - val_accuracy: 0.5909
# Epoch 261/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4458 - accuracy: 0.8939 - val_loss: 0.9445 - val_accuracy: 0.5909
# Epoch 262/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4480 - accuracy: 0.8636 - val_loss: 0.9392 - val_accuracy: 0.5909
# Epoch 263/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4429 - accuracy: 0.8636 - val_loss: 0.9269 - val_accuracy: 0.5909
# Epoch 264/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4372 - accuracy: 0.8788 - val_loss: 0.9388 - val_accuracy: 0.5909
# Epoch 265/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4349 - accuracy: 0.9091 - val_loss: 0.9456 - val_accuracy: 0.5000
# Epoch 266/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4390 - accuracy: 0.8939 - val_loss: 0.9431 - val_accuracy: 0.5000
# Epoch 267/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4344 - accuracy: 0.9091 - val_loss: 0.9519 - val_accuracy: 0.5000
# Epoch 268/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4361 - accuracy: 0.8939 - val_loss: 0.9397 - val_accuracy: 0.5455
# Epoch 269/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4291 - accuracy: 0.8939 - val_loss: 0.9488 - val_accuracy: 0.5455
# Epoch 270/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4263 - accuracy: 0.9091 - val_loss: 0.9373 - val_accuracy: 0.5455
# Epoch 271/300
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4262 - accuracy: 0.9091 - val_loss: 0.9405 - val_accuracy: 0.5455
# Epoch 272/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4235 - accuracy: 0.9091 - val_loss: 0.9059 - val_accuracy: 0.6364
# Epoch 273/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4185 - accuracy: 0.9091 - val_loss: 0.9279 - val_accuracy: 0.5909
# Epoch 274/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4156 - accuracy: 0.9091 - val_loss: 0.9372 - val_accuracy: 0.5909
# Epoch 275/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4135 - accuracy: 0.8939 - val_loss: 0.9422 - val_accuracy: 0.5455
# Epoch 276/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4122 - accuracy: 0.9091 - val_loss: 0.9309 - val_accuracy: 0.5455
# Epoch 277/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4172 - accuracy: 0.8939 - val_loss: 0.9075 - val_accuracy: 0.5909
# Epoch 278/300
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4117 - accuracy: 0.8939 - val_loss: 0.9089 - val_accuracy: 0.5909
# Epoch 279/300
# 3/3 [==============================] - 0s 28ms/step - loss: 0.4108 - accuracy: 0.8939 - val_loss: 0.9221 - val_accuracy: 0.5455
# Epoch 280/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4079 - accuracy: 0.8788 - val_loss: 0.8979 - val_accuracy: 0.6364
# Epoch 281/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4066 - accuracy: 0.8788 - val_loss: 0.9194 - val_accuracy: 0.5909
# Epoch 282/300
# 3/3 [==============================] - 0s 26ms/step - loss: 0.4011 - accuracy: 0.8788 - val_loss: 0.9227 - val_accuracy: 0.5909
# Epoch 283/300
# 3/3 [==============================] - 0s 27ms/step - loss: 0.3991 - accuracy: 0.8939 - val_loss: 0.9163 - val_accuracy: 0.6364
# Epoch 284/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3988 - accuracy: 0.8939 - val_loss: 0.9097 - val_accuracy: 0.5455
# Epoch 285/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3991 - accuracy: 0.8788 - val_loss: 0.9483 - val_accuracy: 0.5909
# Epoch 286/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3959 - accuracy: 0.8788 - val_loss: 0.9328 - val_accuracy: 0.5455
# Epoch 287/300
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3933 - accuracy: 0.8939 - val_loss: 0.9465 - val_accuracy: 0.5909
# Epoch 288/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3902 - accuracy: 0.9242 - val_loss: 0.9388 - val_accuracy: 0.5455
# Epoch 289/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3875 - accuracy: 0.8939 - val_loss: 0.9413 - val_accuracy: 0.5909
# Epoch 290/300
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3858 - accuracy: 0.8939 - val_loss: 0.9226 - val_accuracy: 0.6364
# Epoch 291/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3823 - accuracy: 0.8939 - val_loss: 0.9241 - val_accuracy: 0.6364
# Epoch 292/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3813 - accuracy: 0.8939 - val_loss: 0.9360 - val_accuracy: 0.5909
# Epoch 293/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3792 - accuracy: 0.9091 - val_loss: 0.9394 - val_accuracy: 0.5909
# Epoch 294/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3788 - accuracy: 0.9091 - val_loss: 0.9044 - val_accuracy: 0.6364
# Epoch 295/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3814 - accuracy: 0.8788 - val_loss: 0.9272 - val_accuracy: 0.6364
# Epoch 296/300
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3754 - accuracy: 0.8939 - val_loss: 0.9613 - val_accuracy: 0.5455
# Epoch 297/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3775 - accuracy: 0.8939 - val_loss: 0.9950 - val_accuracy: 0.5909
# Epoch 298/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3800 - accuracy: 0.9091 - val_loss: 0.9564 - val_accuracy: 0.5455
# Epoch 299/300
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3709 - accuracy: 0.8939 - val_loss: 0.9912 - val_accuracy: 0.5909
# Epoch 300/300
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3704 - accuracy: 0.9242 - val_loss: 0.9797 - val_accuracy: 0.5909

# %%
# Save keras model to ONNX file 

from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(keras_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
# Submit keras model: 

#-- Generate predicted y values
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=keras_model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                           custom_metadata={'team': '5'})
# Out:
# 3/3 [==============================] - 0s 4ms/step
# Insert search tags to help users find your model (optional): batch size = 30
# Provide any useful notes about your model (optional): batch size = 30
#
# Your model has been submitted as model version 236
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %% [markdown]
# ## Best models from team 5:
# - Random Forest Classifier with parameters from model 1.2 above
# - Bagging classifier with n_estimators=50, n_jobs=3, random_state=0
# - SVC with {‘C’: 1, ‘degree’: 3, ‘gamma’ : “scale”, ‘kernel’: ‘rbf’, ’cache_size; : 200}
